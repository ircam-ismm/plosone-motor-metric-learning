# %% [markdown]
# # Annotations reliability

# %% [markdown]
# ## figure 3

# %%
from importlib import reload

# %%
import paper
paper = reload(paper)

# %%
pwd
# Out:
# '/home/antoine/Documents/research/motor_metric_learning/plosone_motor_metric_learning/figures'

# %%
A, B, C, D = paper.load_data()

# %%
paper.figure3(B, D)

# %% [markdown]
# ## stats

# %%
a, b, c = paper.stats(C, A)

# %%
a
# Out:
#     Type              Description       ICC          F  df1  df2  \
# 0   ICC1   Single raters absolute  0.838688  16.597502   44   90
# 1   ICC2     Single random raters  0.838528  16.296397   44   88
# 2   ICC3      Single fixed raters  0.836033  16.296397   44   88
# 3  ICC1k  Average raters absolute  0.939750  16.597502   44   90
# 4  ICC2k    Average random raters  0.939683  16.296397   44   88
# 5  ICC3k     Average fixed raters  0.938637  16.296397   44   88
#
#            pval        CI95%
# 0  5.336138e-28  [0.75, 0.9]
# 1  2.846906e-27  [0.75, 0.9]
# 2  2.846906e-27  [0.75, 0.9]
# 3  5.336138e-28  [0.9, 0.96]
# 4  2.846906e-27  [0.9, 0.96]
# 5  2.846906e-27  [0.9, 0.96]

# %%
b
# Out:
#     Type              Description       ICC         F  df1  df2          pval  \
# 0   ICC1   Single raters absolute  0.590375  6.765031   89  270  1.643222e-34
# 1   ICC2     Single random raters  0.589979  6.701828   89  267  5.455219e-34
# 2   ICC3      Single fixed raters  0.587707  6.701828   89  267  5.455219e-34
# 3  ICC1k  Average raters absolute  0.852181  6.765031   89  270  1.643222e-34
# 4  ICC2k    Average random raters  0.851975  6.701828   89  267  5.455219e-34
# 5  ICC3k     Average fixed raters  0.850787  6.701828   89  267  5.455219e-34
#
#           CI95%
# 0  [0.49, 0.68]
# 1  [0.49, 0.68]
# 2  [0.49, 0.68]
# 3    [0.8, 0.9]
# 4   [0.79, 0.9]
# 5   [0.79, 0.9]

# %%
c
# Out:
# Ttest_indResult(statistic=array([2.74838045]), pvalue=array([0.00687304]))

# %% [markdown]
# # Establishing a correlation baseline, without optimisation

# %% [markdown]
# ## table 1

# %%
import paper2
paper2 = reload(paper2)

# %%
df = paper2.getrun()

# %%
df[['dims', 'r_m', 'r_s']]
# Out:
#               dims   r_m   r_s
# 0  p0,a0,g0,p1,p2, 0.759 0.036
# 1   p0,a0,g0,  ,   0.753 0.040
# 2  p0,  ,  ,p1,p2, 0.684 0.040
# 3    ,  ,  ,  ,p2, 0.573 0.066
# 4     ,  ,  ,p1,   0.687 0.054
# 5   p0,  ,  ,  ,   0.495 0.061
# 6     ,  ,g0,  ,   0.697 0.054
# 7     ,a0,  ,  ,   0.713 0.058

# %%
paper2.anova(df)
# Out:
#   Source  ddof1  ddof2      F  p-unc   np2
# 0   cond      7    120 45.777  0.000 0.728

# %% [markdown]
# ## figure 4

# %%
paper2.twoplots()
